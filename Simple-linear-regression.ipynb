# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create a Dataset

# %%
data = {
    'Hours': [1, 2, 3, 4, 5],  # X: Independent Variable
    'Score': [2, 3, 5, 4, 6]   # Y: Dependent Variable
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Hours  Score
# 0      1      2
# 1      2      3
# 2      3      5
# 3      4      4
# 4      5      6

# %% [markdown]
# ## Define Input/Output and Create Model

# %%
X = df[['Hours']]
Y = df['Score']

model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Find slope and Intercept

# %%
print("Slope (m) :", model.coef_[0])
print("Intercept (b) :", model.intercept_)
# Out:
# Slope (m) : 0.8999999999999999
# Intercept (b) : 1.3000000000000003

# %% [markdown]
# ## Predict a New Value
# Suppose a student studies 6 hours.

# %%
n = float(input("Enter Hours Studied: "))

prediction = model.predict([[n]])
print("Predicted Score:", prediction[0])
# Out:
# Predicted Score: 6.699999999999999
# /Users/ibtasam/PycharmProjects/machine_learning/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Plot the Regression

# %%
plt.scatter(X,Y, color = 'red')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.xlabel("Hour Studied")
plt.ylabel("Exam Score")
plt.title("Simple Linear Regression")
plt.legend()
plt.show()
